# %% [markdown]
# <a href="https://colab.research.google.com/github/nithyananthamadroit/python_CSE_projects/blob/python_CSE_dev/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Print Statement

# %%
print("Hello worlds")
# Out:
# Hello world
